# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# M—- hospital is commissioning a model which can distinguish between COVID and non-infected radiography images for the purpose of increasing diagnostic surety to alleviate the tension placed on infectious disease doctors.
#
# We have been provided with data in the form of chest x-rays of 3,616 COVID-19 positive cases along with 10,192 healthy lung images. The task will be to set up a convolutional neural network that is capable of distinguishing between the types of infection with a high level of accuracy, ideally over 90%.

# %% [markdown]
# ## Data Wrangling:

# %% [markdown]
# The first issue presented by the data is that it was disparate photos, untagged, in separate directories. So, the first step was to iterate through the image files and mark whether the images were positive or not based on their folder. From there adding them to a dataframe with a column for positivity, a column for the path, a column for the name of the image file, and an index. This did not list the image itself however, so, the next step was to add an "image" column with the image rendered as an array.
#
# ![Screenshot%20%28995%29.png](attachment:Screenshot%20%28995%29.png)

# %% [markdown]
# We looked at a sample image and made sure the attributes were uniform.
#
# ![Screenshot%20%28997%29.png](attachment:Screenshot%20%28997%29.png)

# %% [markdown]
# ## Exploratory Data Analysis:

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The rate of positive to healthy lungs looks exactly how it should based on the number of image file samples. Nothing was lost in the transfer to the database.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This method has been used in several other medical image data sets where sometimes imgae quality suffers due to the nature of radiography and hospital conditions. The idea is to change the images to grayscale for ease of analysis, slightly augment the gaussian blur, then coloration for ease of differentiation. This was pioneered by Benjamin Graham in a Diabetic Retinopathy dataset released under BSD.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# There is an expected overlap of coloration as well as some outlier pixelation in the positive samples.

# %% [markdown]
# ## Modeling:

# %% [markdown]
# We split the data into test, train, and validation sets.
#
# ![Screenshot%20%28999%29.png](attachment:Screenshot%20%28999%29.png)
#
# Following this we instantiated a Sequential model with the following layers and parameters

# %% [markdown]
# ![Screenshot%20%281001%29.png](attachment:Screenshot%20%281001%29.png)

# %% [markdown]
# Next we trained the model, utilizing an EarlyStopping class. We set it to monitor val_loss and to stop when the value stops decreasing for 4 epochs. This resulted in the model being adequately trained by the 31st epoch.
#
# ![Screenshot%20%281003%29.png](attachment:Screenshot%20%281003%29.png)

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![Screenshot%20%281007%29.png](attachment:Screenshot%20%281007%29.png)

# %% [markdown]
# ![Screenshot%20%281008%29.png](attachment:Screenshot%20%281008%29.png)

# %% [markdown]
# ![Screenshot%20%281009%29.png](attachment:Screenshot%20%281009%29.png)

# %% [markdown]
# Though there is a bit of criss-crossing between the training and validation, we do resist overfitting.
# An accuracy of .97 with a loss of .09 is fantastic. We might be served by further generalizing the validation data, but overall the model is great and should be more than sufficient for a doctor's aid in daignosis.
